# %% [markdown]
# # AI Commerce Agent
#
# # AI Product Assistant Agemt
# ---

# %%
import pandas as pd

# df = pd.read_csv(r"C:\Users\lenovo\Downloads\archive\amazon_products.csv")
# categories = pd.read_csv(r"C:\Users\lenovo\Downloads\archive\amazon_categories.csv")
df = pd.read_csv(r"C:\Users\lenovo\Downloads\amazon_products_cleaned.csv")
df.head()
# Out:
#    Unnamed: 0 Product Category Product Subcategory  \
# 0           0      Electronics         Smartphones
# 1           1      Electronics         Smartphones
# 2           2      Electronics         Smartphones
# 3           3      Electronics         Smartphones
# 4           4      Electronics         Smartphones
#
#                                         Product Name  \
# 0  SAMSUNG Galaxy S25 Ultra Cell Phone, 512GB AI ...
# 1  SAMSUNG Galaxy A16 5G A Series Cell Phone, Unl...
# 2  Tracfone | Motorola Moto g Play 2024 | Locked ...
# 3  SAMSUNG Galaxy S24 FE AI Phone, 128GB Unlocked...
# 4  Moto G 5G | 2024 | Unlocked | Made for US 4/12...
#
#                                          Product URL Product Price  \
# 0  https://www.amazon.com/SAMSUNG-Smartphone-Unlo...    $1,219.99
# 1  https://www.amazon.com/SAMSUNG-Unlocked-Smartp...      $174.99
# 2  https://www.amazon.com/Tracfone-Motorola-5000m...       $39.88
# ...

# %%
# categories.head()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Product Category       1
# Product Subcategory    1
# Product Name           3
# Product URL            1
# Product Price          1
# Product Rating         1
# Total Ratings          3
# Product Image          1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Product Category       0
# Product Subcategory    0
# Product Name           0
# Product URL            0
# Product Price          0
# Product Rating         0
# Total Ratings          0
# Product Image          0
# dtype: int64

# %%
df['Product Price'].str.replace('$','').replace(' ','')
# Out:
# 0        1,219.99
# 1          174.99
# 2           39.88
# 3          498.95
# 4          149.99
#            ...
# 42428       139.00
# 42429       379.00
# 42430       143.99
# 42431       168.00
# 42432       118.99
# Name: Product Price, Length: 42430, dtype: str

# %%
df['Product Price'] = df['Product Price'].str.replace('$','').str.replace(',','').str.strip()

# %%
df['Product Price'] = df['Product Price'].astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0 Product Category Product Subcategory  \
# 0           0      Electronics         Smartphones
# 1           1      Electronics         Smartphones
# 2           2      Electronics         Smartphones
# 3           3      Electronics         Smartphones
# 4           4      Electronics         Smartphones
#
#                                         Product Name  \
# 0  SAMSUNG Galaxy S25 Ultra Cell Phone, 512GB AI ...
# 1  SAMSUNG Galaxy A16 5G A Series Cell Phone, Unl...
# 2  Tracfone | Motorola Moto g Play 2024 | Locked ...
# 3  SAMSUNG Galaxy S24 FE AI Phone, 128GB Unlocked...
# 4  Moto G 5G | 2024 | Unlocked | Made for US 4/12...
#
#                                          Product URL  Product Price  \
# 0  https://www.amazon.com/SAMSUNG-Smartphone-Unlo...        1219.99
# 1  https://www.amazon.com/SAMSUNG-Unlocked-Smartp...         174.99
# 2  https://www.amazon.com/Tracfone-Motorola-5000m...          39.88
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 42430 entries, 0 to 42432
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           42430 non-null  int64
#  1   Product Category     42430 non-null  str
#  2   Product Subcategory  42430 non-null  str
#  3   Product Name         42430 non-null  str
#  4   Product URL          42430 non-null  str
#  5   Product Price        42430 non-null  str
#  6   Product Rating       42430 non-null  float64
#  7   Total Ratings        42430 non-null  str
#  8   Product Image        42430 non-null  str
# dtypes: float64(1), int64(1), str(7)
# memory usage: 38.3 MB

# %%
df['Product Rating'] = df['Product Rating'].astype(float)

# %%
df['Total Ratings'] = df['Total Ratings'].str.replace(',','').str.strip().astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 42430 entries, 0 to 42432
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           42430 non-null  int64
#  1   Product Category     42430 non-null  str
#  2   Product Subcategory  42430 non-null  str
#  3   Product Name         42430 non-null  str
#  4   Product URL          42430 non-null  str
#  5   Product Price        42430 non-null  str
#  6   Product Rating       42430 non-null  float64
#  7   Total Ratings        42430 non-null  int64
#  8   Product Image        42430 non-null  str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 38.1 MB

# %%
# import pandas as pd

# df = pd.read_csv("data/products.csv")

# def search_products(category, budget):
#     results = df[
#         # (df['category_id'].str.contains(category, case=False)) &
#         # (df['price'] <= budget)
#         (df['category_id'] == category) &
#         (df['price'] <= budget)
#     ]
#     return results

def search_products(category, budget):
    results = df[
        (df['Product Name'].str.contains(category, case=False)) &
        (df['Product Price'] <= budget) &
        (df['Product Subcategory'].str.contains('smartphone', case=False))
    ]
    return results

search_products('phone', 10000)
# Out:
#     Unnamed: 0 Product Category Product Subcategory  \
# 0            0      Electronics         Smartphones
# 1            1      Electronics         Smartphones
# 3            3      Electronics         Smartphones
# 7            7      Electronics         Smartphones
# 9            9      Electronics         Smartphones
# 11          11      Electronics         Smartphones
# 12          12      Electronics         Smartphones
# 13          13      Electronics         Smartphones
# 14          14      Electronics         Smartphones
# 15          15      Electronics         Smartphones
# 17          17      Electronics         Smartphones
# 18          18      Electronics         Smartphones
# 22          22      Electronics         Smartphones
# 24          24      Electronics         Smartphones
# 25          25      Electronics         Smartphones
# 26          26      Electronics         Smartphones
# 28          28      Electronics         Smartphones
# ...

# %%
df = pd.read_csv(r"C:\Users\lenovo\Downloads\archive\amazon_products.csv")

# %%
df.head()
# Out:
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                              productURL  stars  reviews   price  listPrice  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# ...

# %%
def search_products(category, budget):
    results = df[
        (df['title'].str.contains(category, case=False)) &
        (df['price'] <= budget)
    ]
    return results

search_products('men bag', 10000)
# Out:
#                asin                                              title  \
# 6710     B0BC2XN8Q7  Jeans for Women Baggy Cargo Pants Men Y2K Para...
# 41932    B0B2WD65GW  Creative Skull Dino Keychain for Men Bags Back...
# 221084   B0BYD3WRNS  Konelia Travel Bag Convertible Garment Weekend...
# 221103   B0CBQPBXDL  Charms for Bogg Bag Bag Beach Tote Bag Rubber ...
# 221822   B0CBQQXBQ4  Charms for Bogg Bag Beach Tote Bag Rubber Beac...
# ...             ...                                                ...
# 1394904  B0BWYCL6Z4  2 Pcs Luggage Tag for Suitcases, Cute Leather ...
# 1396979  B0C4DV9QXM  Rimilak 10 Pack PVC Luggage Tags for Suitcase,...
# 1397464  B09P341625  6 Pieces Makeup Bag Set Travel Cosmetic Bag Co...
# 1397909  B0C8MGVLV1  Hsxnam 2 Pack PU Leather Luggage Tags for Suit...
# 1404151  B0C2V5T5PD  XIQIGUGUA 2 Pack Luggage Tag for Suitcases, Ho...
#
#                                                     imgUrl  \
# ...

# %% [markdown]
# ---
# ---
# ---
# ---

# %%
import os
os.listdir('resources')
# Out:
# ['Cars Datasets 2025.csv',
#  'Flipkart_trending_mobils_feb_2026.csv',
#  'laptop.csv',
#  'laptops data details.txt',
#  'Mobiles Dataset (2025).csv']

# %% [markdown]
# # Mobile phones data produced in <= 2025

# %%
# Mobile phones data produced in <= 2025
phones = pd.read_csv('resources/Mobiles Dataset (2025).csv', encoding='latin1')
phones.head()
# Out:
#   Company Name            Model Name Mobile Weight  RAM Front Camera  \
# 0        Apple       iPhone 16 128GB          174g  6GB         12MP
# 1        Apple       iPhone 16 256GB          174g  6GB         12MP
# 2        Apple       iPhone 16 512GB          174g  6GB         12MP
# 3        Apple  iPhone 16 Plus 128GB          203g  6GB         12MP
# 4        Apple  iPhone 16 Plus 256GB          203g  6GB         12MP
#
#   Back Camera   Processor Battery Capacity Screen Size  \
# 0        48MP  A17 Bionic         3,600mAh  6.1 inches
# 1        48MP  A17 Bionic         3,600mAh  6.1 inches
# 2        48MP  A17 Bionic         3,600mAh  6.1 inches
# 3        48MP  A17 Bionic         4,200mAh  6.7 inches
# 4        48MP  A17 Bionic         4,200mAh  6.7 inches
#
#   Launched Price (Pakistan) Launched Price (India) Launched Price (China)  \
# 0               PKR 224,999             INR 79,999              CNY 5,799
# ...

# %% [markdown]
# ## Preprocessing

# %%
phones.columns
# Out:
# Index(['Company Name', 'Model Name', 'Mobile Weight', 'RAM', 'Front Camera',
#        'Back Camera', 'Processor', 'Battery Capacity', 'Screen Size',
#        'Launched Price (Pakistan)', 'Launched Price (India)',
#        'Launched Price (China)', 'Launched Price (USA)',
#        'Launched Price (Dubai)', 'Launched Year'],
#       dtype='str')

# %%
phones.drop(['Launched Price (India)','Launched Price (China)','Launched Price (Pakistan)','Launched Price (Dubai)'], axis=1, inplace=True)

# %%
phones.head(3)
# Out:
#   Company Name       Model Name Mobile Weight  RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB          174g  6GB         12MP        48MP
# 1        Apple  iPhone 16 256GB          174g  6GB         12MP        48MP
# 2        Apple  iPhone 16 512GB          174g  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size Launched Price (USA)  Launched Year
# 0  A17 Bionic         3,600mAh  6.1 inches              USD 799           2024
# 1  A17 Bionic         3,600mAh  6.1 inches              USD 849           2024
# 2  A17 Bionic         3,600mAh  6.1 inches              USD 899           2024

# %%
phones['Launched Price (USA)'] = phones['Launched Price (USA)'].str.replace('USD','').str.replace(',','').str.strip().astype(float)

phones.head()
# Out:
#   Company Name            Model Name Mobile Weight  RAM Front Camera  \
# 0        Apple       iPhone 16 128GB          174g  6GB         12MP
# 1        Apple       iPhone 16 256GB          174g  6GB         12MP
# 2        Apple       iPhone 16 512GB          174g  6GB         12MP
# 3        Apple  iPhone 16 Plus 128GB          203g  6GB         12MP
# 4        Apple  iPhone 16 Plus 256GB          203g  6GB         12MP
#
#   Back Camera   Processor Battery Capacity Screen Size  Launched Price (USA)  \
# 0        48MP  A17 Bionic         3,600mAh  6.1 inches                 799.0
# 1        48MP  A17 Bionic         3,600mAh  6.1 inches                 849.0
# 2        48MP  A17 Bionic         3,600mAh  6.1 inches                 899.0
# 3        48MP  A17 Bionic         4,200mAh  6.7 inches                 899.0
# 4        48MP  A17 Bionic         4,200mAh  6.7 inches                 949.0
#
#    Launched Year
# 0           2024
# 1           2024
# 2           2024
# ...

# %%
phones['Mobile Weight'] = phones['Mobile Weight'].str.replace('g','').str.strip().astype(float)

# %%
# phones['Camera'] = phones['Back Camera'] + ' | ' + phones['Front Camera'] + ' Front Camera'
# phones.drop("Camera", inplace=True, axis=1)

# %%
phones.head()
# Out:
#   Company Name            Model Name  Mobile Weight  RAM Front Camera  \
# 0        Apple       iPhone 16 128GB          174.0  6GB         12MP
# 1        Apple       iPhone 16 256GB          174.0  6GB         12MP
# 2        Apple       iPhone 16 512GB          174.0  6GB         12MP
# 3        Apple  iPhone 16 Plus 128GB          203.0  6GB         12MP
# 4        Apple  iPhone 16 Plus 256GB          203.0  6GB         12MP
#
#   Back Camera   Processor Battery Capacity Screen Size  Launched Price (USA)  \
# 0        48MP  A17 Bionic         3,600mAh  6.1 inches                 799.0
# 1        48MP  A17 Bionic         3,600mAh  6.1 inches                 849.0
# 2        48MP  A17 Bionic         3,600mAh  6.1 inches                 899.0
# 3        48MP  A17 Bionic         4,200mAh  6.7 inches                 899.0
# 4        48MP  A17 Bionic         4,200mAh  6.7 inches                 949.0
#
#    Launched Year
# 0           2024
# 1           2024
# 2           2024
# ...

# %%
phones['Company Name'] + ' ' +phones['Model Name']
# Out:
# 0             Apple iPhone 16 128GB
# 1             Apple iPhone 16 256GB
# 2             Apple iPhone 16 512GB
# 3        Apple iPhone 16 Plus 128GB
# 4        Apple iPhone 16 Plus 256GB
#                    ...
# 925               Poco Pad 5G 128GB
# 926               Poco Pad 5G 256GB
# 927    Samsung Galaxy Z Fold6 256GB
# 928    Samsung Galaxy Z Fold6 512GB
# 929      Samsung Galaxy Z Fold6 1TB
# Length: 930, dtype: str

# %%
phones
# Out:
#     Company Name            Model Name  Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174.0   6GB             12MP
# 1          Apple       iPhone 16 256GB          174.0   6GB             12MP
# 2          Apple       iPhone 16 512GB          174.0   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203.0   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203.0   6GB             12MP
# ..           ...                   ...            ...   ...              ...
# 925         Poco          Pad 5G 128GB          571.0   8GB              8MP
# 926         Poco          Pad 5G 256GB          571.0   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239.0  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239.0  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239.0  12GB  10MP, 4MP (UDC)
#
# ...

# %%
phones.drop('Name', axis=1, inplace = True)

# %%
phones.isnull().sum()
# Out:
# Company Name            0
# Model Name              0
# Mobile Weight           0
# RAM                     0
# Front Camera            0
# Back Camera             0
# Processor               0
# Battery Capacity        0
# Screen Size             0
# Launched Price (USA)    0
# Launched Year           0
# dtype: int64

# %%
phones.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company Name          930 non-null    str
#  1   Model Name            930 non-null    str
#  2   Mobile Weight         930 non-null    float64
#  3   RAM                   930 non-null    str
#  4   Front Camera          930 non-null    str
#  5   Back Camera           930 non-null    str
#  6   Processor             930 non-null    str
#  7   Battery Capacity      930 non-null    str
#  8   Screen Size           930 non-null    str
#  9   Launched Price (USA)  930 non-null    float64
#  10  Launched Year         930 non-null    int64
# dtypes: float64(2), int64(1), str(8)
# memory usage: 145.7 KB

# %% [markdown]
# ---

# %% [markdown]
# # Mobile phones data produced in 2026

# %%
# Mobile phones data produced in 2026
phones26 = pd.read_csv('resources/Flipkart_trending_mobils_feb_2026.csv')
phones26.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0   Samsung Galaxy F70e 5G (Limelight Green, 128 GB)
# 1           1                    Apple iPhone 16 (White, 128 GB)
# 2           2   MOTOROLA g57 power 5G (Pantone Fluidity, 128 GB)
# 3           3                    Apple iPhone 16 (Black, 128 GB)
# 4           4  vivo T4 Lite 5G Charger in the Box (Titanium G...
#
#                                                image  \
# 0  src="https://rukminim2.flixcart.com/image/312/...
# 1  src="https://rukminim2.flixcart.com/image/312/...
# 2  src="https://rukminim2.flixcart.com/image/312/...
# 3  src="https://rukminim2.flixcart.com/image/312/...
# 4  src="https://rukminim2.flixcart.com/image/312/...
#
#                              rating  warrenty  \
# 0  2,08,961 Ratings & 6,706 Reviews       NaN
# 1      17,642 Ratings & 944 Reviews       NaN
# 2  2,08,961 Ratings & 6,706 Reviews       NaN
# 3    45,190 Ratings & 1,306 Reviews       NaN
# ...

# %% [markdown]
# ## preprocessing

# %%
c = phones26.columns
c
# Out:
# Index(['Unnamed: 0', 'name', 'image', 'rating', 'warrenty', 'display',
#        'camera', 'processor', 'ram and rom', 'price'],
#       dtype='str')

# %%
phones26.drop(c[0], axis=1, inplace=True)
phones26.head(1)
# Out:
#                                                name  \
# 0  Samsung Galaxy F70e 5G (Limelight Green, 128 GB)
#
#                                                image  \
# 0  src="https://rukminim2.flixcart.com/image/312/...
#
#                              rating  warrenty  \
# 0  2,08,961 Ratings & 6,706 Reviews       NaN
#
#                             display                         camera  \
# 0  17.12 cm (6.74 inch) HD+ Display  50MP + 2MP | 8MP Front Camera
#
#                  processor                                   ram and rom  \
# 0  6000 mAh Li-ion Battery  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB
#
#      price
# 0  ₹11,749

# %%
phones26.drop('warrenty', axis=1, inplace=True)
phones26.head(1)
# Out:
#                                                name  \
# 0  Samsung Galaxy F70e 5G (Limelight Green, 128 GB)
#
#                                                image  \
# 0  src="https://rukminim2.flixcart.com/image/312/...
#
#                              rating                           display  \
# 0  2,08,961 Ratings & 6,706 Reviews  17.12 cm (6.74 inch) HD+ Display
#
#                           camera                processor  \
# 0  50MP + 2MP | 8MP Front Camera  6000 mAh Li-ion Battery
#
#                                     ram and rom    price
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB  ₹11,749

# %%
phones26.drop('rating', axis=1, inplace=True)
phones26.drop('image', axis=1, inplace=True)

phones26.head(1)
# Out:
#                                                name  \
# 0  Samsung Galaxy F70e 5G (Limelight Green, 128 GB)
#
#                             display                         camera  \
# 0  17.12 cm (6.74 inch) HD+ Display  50MP + 2MP | 8MP Front Camera
#
#                  processor                                   ram and rom  \
# 0  6000 mAh Li-ion Battery  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB
#
#      price
# 0  ₹11,749

# %%
phones.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight  RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB          174.0  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size  Launched Price (USA)  \
# 0  A17 Bionic         3,600mAh  6.1 inches                 799.0
#
#    Launched Year
# 0           2024

# %%
phones26['name'].str.split(' ', n=1).str.get(0)
# Out:
# 0       Samsung
# 1         Apple
# 2      MOTOROLA
# 3         Apple
# 4          vivo
#          ...
# 835         hmd
# 836        vivo
# 837    MOTOROLA
# 838      realme
# 839    Kechaoda
# Name: name, Length: 840, dtype: object

# %%
phones26.insert(loc=0, column='Company Name', value=phones26['name'].str.split(' ', n=1).str.get(0))

# %%
phones26
# Out:
#     Company Name                                               name  \
# 0        Samsung   Samsung Galaxy F70e 5G (Limelight Green, 128 GB)
# 1          Apple                    Apple iPhone 16 (White, 128 GB)
# 2       MOTOROLA   MOTOROLA g57 power 5G (Pantone Fluidity, 128 GB)
# 3          Apple                    Apple iPhone 16 (Black, 128 GB)
# 4           vivo  vivo T4 Lite 5G Charger in the Box (Titanium G...
# ..           ...                                                ...
# 835          hmd  hmd 110 Dual Sim Keypad Phone with Built-in Sc...
# 836         vivo             vivo Y19s 5G (Majestic Green, 64.0 GB)
# 837     MOTOROLA        MOTOROLA Edge 70 (PANTONE Lily Pad, 256 GB)
# 838       realme          realme P3 Ultra 5G (Neptune Blue, 128 GB)
# 839     Kechaoda                                       Kechaoda A27
#
#                                           display  \
# 0                17.12 cm (6.74 inch) HD+ Display
# ...

# %%
phones26['name'].str.split(' ', n=1).str.get(1)
# Out:
# 0               Galaxy F70e 5G (Limelight Green, 128 GB)
# 1                              iPhone 16 (White, 128 GB)
# 2                g57 power 5G (Pantone Fluidity, 128 GB)
# 3                              iPhone 16 (Black, 128 GB)
# 4      T4 Lite 5G Charger in the Box (Titanium Gold, ...
#                              ...
# 835    110 Dual Sim Keypad Phone with Built-in Scan &...
# 836                    Y19s 5G (Majestic Green, 64.0 GB)
# 837                   Edge 70 (PANTONE Lily Pad, 256 GB)
# 838                   P3 Ultra 5G (Neptune Blue, 128 GB)
# 839                                                  A27
# Name: name, Length: 840, dtype: object

# %%
phones26.insert(loc=1, column='Model Name', value=phones26['name'].str.split(' ', n=1).str.get(1))
phones26.head(2)
# Out:
#   Company Name                                Model Name  \
# 0      Samsung  Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                 iPhone 16 (White, 128 GB)
#
#                                                name  \
# 0  Samsung Galaxy F70e 5G (Limelight Green, 128 GB)
# 1                   Apple iPhone 16 (White, 128 GB)
#
#                                         display  \
# 0              17.12 cm (6.74 inch) HD+ Display
# 1  15.49 cm (6.1 inch) Super Retina XDR Display
#
#                             camera                             processor  \
# 0    50MP + 2MP | 8MP Front Camera               6000 mAh Li-ion Battery
# 1  48MP + 12MP | 12MP Front Camera  A18 Chip, 6 Core Processor Processor
#
#                                     ram and rom    price
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB  ₹11,749
# 1                                    128 GB ROM  ₹64,900

# %%
phones26.drop('name', axis=1, inplace=True)
phones26.head(3)
# Out:
#   Company Name                                Model Name  \
# 0      Samsung  Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                 iPhone 16 (White, 128 GB)
# 2     MOTOROLA   g57 power 5G (Pantone Fluidity, 128 GB)
#
#                                         display  \
# 0              17.12 cm (6.74 inch) HD+ Display
# 1  15.49 cm (6.1 inch) Super Retina XDR Display
# 2         17.07 cm (6.72 inch) Full HD+ Display
#
#                             camera                             processor  \
# 0    50MP + 2MP | 8MP Front Camera               6000 mAh Li-ion Battery
# 1  48MP + 12MP | 12MP Front Camera  A18 Chip, 6 Core Processor Processor
# 2    50MP + 8MP | 8MP Front Camera                      7000 mAh Battery
#
#                                     ram and rom    price
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB  ₹11,749
# 1                                    128 GB ROM  ₹64,900
# 2                         8 GB RAM | 128 GB ROM  ₹13,999

# %%
phones.head(2)
# Out:
#   Company Name       Model Name  Mobile Weight  RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB          174.0  6GB         12MP        48MP
# 1        Apple  iPhone 16 256GB          174.0  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size  Launched Price (USA)  \
# 0  A17 Bionic         3,600mAh  6.1 inches                 799.0
# 1  A17 Bionic         3,600mAh  6.1 inches                 849.0
#
#    Launched Year
# 0           2024
# 1           2024

# %%
phones26['camera'].str.split('|', n=1).str.get(0).str.strip()
# Out:
# 0             50MP + 2MP
# 1            48MP + 12MP
# 2             50MP + 8MP
# 3            48MP + 12MP
# 4             50MP + 2MP
#              ...
# 835    0.2MP Rear Camera
# 836        13MP + 0.08MP
# 837          50MP + 50MP
# 838           50MP + 8MP
# 839                  0MP
# Name: camera, Length: 840, dtype: object

# %%
phones26['Back Camera'] = phones26['camera'].str.split('|', n=1).str.get(0).str.strip()
phones26.head(2)
# Out:
#   Company Name                                Model Name  \
# 0      Samsung  Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                 iPhone 16 (White, 128 GB)
#
#                                         display  \
# 0              17.12 cm (6.74 inch) HD+ Display
# 1  15.49 cm (6.1 inch) Super Retina XDR Display
#
#                             camera                             processor  \
# 0    50MP + 2MP | 8MP Front Camera               6000 mAh Li-ion Battery
# 1  48MP + 12MP | 12MP Front Camera  A18 Chip, 6 Core Processor Processor
#
#                                     ram and rom    price  Back Camera
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB  ₹11,749   50MP + 2MP
# 1                                    128 GB ROM  ₹64,900  48MP + 12MP

# %%
phones26['camera'].str.split('|', n=1).str.get(1).str.replace('Front Camera','').str.strip()
# Out:
# 0       8MP
# 1      12MP
# 2       8MP
# 3      12MP
# 4       5MP
#        ...
# 835     NaN
# 836     5MP
# 837    50MP
# 838    16MP
# 839     0MP
# Name: camera, Length: 840, dtype: object

# %%
phones26['Front Camera'] = phones26['camera'].str.split('|', n=1).str.get(1).str.replace('Front Camera','').str.strip()
phones26.head(2)
# Out:
#   Company Name                                Model Name  \
# 0      Samsung  Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                 iPhone 16 (White, 128 GB)
#
#                                         display  \
# 0              17.12 cm (6.74 inch) HD+ Display
# 1  15.49 cm (6.1 inch) Super Retina XDR Display
#
#                             camera                             processor  \
# 0    50MP + 2MP | 8MP Front Camera               6000 mAh Li-ion Battery
# 1  48MP + 12MP | 12MP Front Camera  A18 Chip, 6 Core Processor Processor
#
#                                     ram and rom    price  Back Camera  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB  ₹11,749   50MP + 2MP
# 1                                    128 GB ROM  ₹64,900  48MP + 12MP
#
#   Front Camera
# 0          8MP
# 1         12MP

# %%
phones.drop('Mobile Weight', axis=1, inplace=True)

# %%
phones26.drop('camera', axis=1, inplace=True)

# %%
phones.head(1)
# Out:
#   Company Name       Model Name  RAM Front Camera Back Camera   Processor  \
# 0        Apple  iPhone 16 128GB  6GB         12MP        48MP  A17 Bionic
#
#   Battery Capacity Screen Size  Launched Price (USA)  Launched Year
# 0         3,600mAh  6.1 inches                 799.0           2024

# %%
phones26.head(1)
# Out:
#   Company Name                                Model Name  \
# 0      Samsung  Galaxy F70e 5G (Limelight Green, 128 GB)
#
#                             display                processor  \
# 0  17.12 cm (6.74 inch) HD+ Display  6000 mAh Li-ion Battery
#
#                                     ram and rom    price Back Camera  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB  ₹11,749  50MP + 2MP
#
#   Front Camera
# 0          8MP

# %%
phones26['Battery Capacity'] = 0
phones26['Launched Year'] = 0

# %%
phones26.columns
# Out:
# Index(['Company Name', 'Model Name', 'display', 'processor', 'ram and rom',
#        'price', 'Back Camera', 'Front Camera', 'Battery Capacity',
#        'Launched Year'],
#       dtype='str')

# %%
phones26 = phones26[['Company Name','Model Name', 'ram and rom','Front Camera','Back Camera','processor','Battery Capacity', 'display', 'price','Launched Year']]

# %%
phones26.head()
# Out:
#   Company Name                                         Model Name  \
# 0      Samsung           Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                          iPhone 16 (White, 128 GB)
# 2     MOTOROLA            g57 power 5G (Pantone Fluidity, 128 GB)
# 3        Apple                          iPhone 16 (Black, 128 GB)
# 4         vivo  T4 Lite 5G Charger in the Box (Titanium Gold, ...
#
#                                     ram and rom Front Camera  Back Camera  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB          8MP   50MP + 2MP
# 1                                    128 GB ROM         12MP  48MP + 12MP
# 2                         8 GB RAM | 128 GB ROM          8MP   50MP + 8MP
# 3                                    128 GB ROM         12MP  48MP + 12MP
# 4   4 GB RAM | 64 GB ROM | Expandable Upto 2 TB          5MP   50MP + 2MP
#
#                               processor  Battery Capacity  \
# 0               6000 mAh Li-ion Battery                 0
# ...

# %%
print(phones.columns)
print('_'*100)
print(phones26.columns)
# Out:
# Index(['Company Name', 'Model Name', 'RAM', 'Front Camera', 'Back Camera',
#        'Processor', 'Battery Capacity', 'Screen Size', 'Launched Price (USA)',
#        'Launched Year'],
#       dtype='str')
# ____________________________________________________________________________________________________
# Index(['Company Name', 'Model Name', 'ram and rom', 'Front Camera',
#        'Back Camera', 'processor', 'Battery Capacity', 'display', 'price',
#        'Launched Year'],
#       dtype='str')

# %%
phones26.columns = phones.columns

# %%
phones26.columns
# Out:
# Index(['Company Name', 'Model Name', 'RAM', 'Front Camera', 'Back Camera',
#        'Processor', 'Battery Capacity', 'Screen Size', 'Launched Price (USA)',
#        'Launched Year'],
#       dtype='str')

# %%
phones26.head()
# Out:
#   Company Name                                         Model Name  \
# 0      Samsung           Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                          iPhone 16 (White, 128 GB)
# 2     MOTOROLA            g57 power 5G (Pantone Fluidity, 128 GB)
# 3        Apple                          iPhone 16 (Black, 128 GB)
# 4         vivo  T4 Lite 5G Charger in the Box (Titanium Gold, ...
#
#                                             RAM Front Camera  Back Camera  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB          8MP   50MP + 2MP
# 1                                    128 GB ROM         12MP  48MP + 12MP
# 2                         8 GB RAM | 128 GB ROM          8MP   50MP + 8MP
# 3                                    128 GB ROM         12MP  48MP + 12MP
# 4   4 GB RAM | 64 GB ROM | Expandable Upto 2 TB          5MP   50MP + 2MP
#
#                               Processor  Battery Capacity  \
# 0               6000 mAh Li-ion Battery                 0
# ...

# %%
phones.rename(columns={'Launched Price (USA)':'Price'}, inplace=True)

# %%
phones26.columns = phones.columns

# %%
# Convert prices into USD
phones26['Price'].str.replace('₹','').str.replace(',','').str.strip().astype(float) *0.01
# Out:
# 0      117.49
# 1      649.00
# 2      139.99
# 3      649.00
# 4      109.99
#         ...
# 835     11.89
# 836    124.99
# 837    329.99
# 838    239.99
# 839      8.99
# Name: Price, Length: 840, dtype: float64

# %%
phones26['Price'] = phones26['Price'].str.replace('₹','').str.replace(',','').str.strip().astype(float) *0.01

# %%
phones26.head()
# Out:
#   Company Name                                         Model Name  \
# 0      Samsung           Galaxy F70e 5G (Limelight Green, 128 GB)
# 1        Apple                          iPhone 16 (White, 128 GB)
# 2     MOTOROLA            g57 power 5G (Pantone Fluidity, 128 GB)
# 3        Apple                          iPhone 16 (Black, 128 GB)
# 4         vivo  T4 Lite 5G Charger in the Box (Titanium Gold, ...
#
#                                             RAM Front Camera  Back Camera  \
# 0  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB          8MP   50MP + 2MP
# 1                                    128 GB ROM         12MP  48MP + 12MP
# 2                         8 GB RAM | 128 GB ROM          8MP   50MP + 8MP
# 3                                    128 GB ROM         12MP  48MP + 12MP
# 4   4 GB RAM | 64 GB ROM | Expandable Upto 2 TB          5MP   50MP + 2MP
#
#                               Processor  Battery Capacity  \
# 0               6000 mAh Li-ion Battery                 0
# ...

# %%
mobile_phones = pd.concat([phones,phones26], ignore_index=True)
mobile_phones
# Out:
#      Company Name                                         Model Name  \
# 0           Apple                                    iPhone 16 128GB
# 1           Apple                                    iPhone 16 256GB
# 2           Apple                                    iPhone 16 512GB
# 3           Apple                               iPhone 16 Plus 128GB
# 4           Apple                               iPhone 16 Plus 256GB
# ...           ...                                                ...
# 1765          hmd  110 Dual Sim Keypad Phone with Built-in Scan &...
# 1766         vivo                  Y19s 5G (Majestic Green, 64.0 GB)
# 1767     MOTOROLA                 Edge 70 (PANTONE Lily Pad, 256 GB)
# 1768       realme                 P3 Ultra 5G (Neptune Blue, 128 GB)
# 1769     Kechaoda                                                A27
#
#                                                 RAM Front Camera  \
# 0                                               6GB         12MP
# ...

# %%
mobile_phones.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company Name      1770 non-null   object
#  1   Model Name        1770 non-null   object
#  2   RAM               1770 non-null   str
#  3   Front Camera      1546 non-null   object
#  4   Back Camera       1770 non-null   object
#  5   Processor         1767 non-null   str
#  6   Battery Capacity  1770 non-null   object
#  7   Screen Size       1770 non-null   str
#  8   Price             1770 non-null   float64
#  9   Launched Year     1770 non-null   int64
# dtypes: float64(1), int64(1), object(5), str(3)
# memory usage: 232.2+ KB

# %% [markdown]
# Storing the final dataframe

# %%
mobile_phones.to_csv('mobile_phones.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # laptops data

# %%
# laptops data
laptops = pd.read_csv('resources/laptop.csv')
laptops.head()
# Out:
#    Unnamed: 0    Brand                                               Name  \
# 0           0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1           1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2           3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3           4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4           6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
#
#    Price            Processor_Name Processor_Brand     RAM_Expandable  \
# 0  22990        MediaTek Octa-core        MediaTek     Not Expandable
# 1  36289     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2  78500  Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3  55490  Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4  21990  Intel Core i3 (11th Gen)           Intel     Not Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# ...

# %%
c = laptops.columns
c
# Out:
# Index(['Unnamed: 0', 'Brand', 'Name', 'Price', 'Processor_Name',
#        'Processor_Brand', 'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz',
#        'Display_type', 'Display', 'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter',
#        'Battery_Life'],
#       dtype='str')

# %%
laptops.drop(c[0], axis=1, inplace=True)

# %%
laptops.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            3976 non-null   str
#  1   Name             3976 non-null   str
#  2   Price            3976 non-null   float64
#  3   Processor_Name   3976 non-null   str
#  4   Processor_Brand  3976 non-null   str
#  5   RAM_Expandable   3976 non-null   str
#  6   RAM              3976 non-null   str
#  7   RAM_TYPE         3976 non-null   str
#  8   Ghz              3976 non-null   str
#  9   Display_type     3976 non-null   str
#  10  Display          3976 non-null   str
#  11  GPU              3968 non-null   str
#  12  GPU_Brand        3972 non-null   str
#  13  SSD              3976 non-null   str
#  14  HDD              3976 non-null   str
#  15  Adapter          3976 non-null   str
#  16  Battery_Life     3558 non-null   str
# dtypes: float64(1), str(16)
# memory usage: 1.6 MB

# %%
# Convert price from indian currency into USD
laptops['Price'] = laptops['Price'] * 0.01

# %%
laptops.head(2)
# Out:
#     Brand                                               Name   Price  \
# 0      HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  229.90
# 1  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  362.89
#
#           Processor_Name Processor_Brand     RAM_Expandable    RAM  \
# 0     MediaTek Octa-core        MediaTek     Not Expandable  4 GB
# 1  AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable  8 GB
#
#      RAM_TYPE                 Ghz Display_type Display                  GPU  \
# 0    DDR4 RAM   2.0 Ghz Processor          LED   11.6   Integrated Graphics
# 1   DDR4 RAM    4.0 Ghz Processor          LCD   15.6                Radeon
#
#   GPU_Brand                 SSD     HDD Adapter               Battery_Life
# 0  MediaTek   64 GB SSD Storage  No HDD      45   Upto 12 Hrs Battery Life
# 1       AMD  512 GB SSD Storage  No HDD      65   Upto 11 Hrs Battery Life

# %%
laptops.isnull().sum()
# Out:
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
# laptops.dropna(subset=df.columns.drop('Battery') ,inplace=True)

# %%
laptops.to_csv('laptops.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # cars data

# %%
# cars data
cars = pd.read_csv('resources/Cars Datasets 2025.csv', encoding='latin1')
cars.head()
# Out:
#   Company Names     Cars Names      Engines CC/Battery Capacity HorsePower  \
# 0       FERRARI  SF90 STRADALE           V8             3990 cc     963 hp
# 1   ROLLS ROYCE        PHANTOM          V12             6749 cc     563 hp
# 2          Ford            KA+  1.2L Petrol            1,200 cc   70-85 hp
# 3      MERCEDES        GT 63 S           V8            3,982 cc     630 hp
# 4          AUDI     AUDI R8 Gt          V10            5,204 cc     602 hp
#
#   Total Speed Performance(0 - 100 )KM/H      Cars Prices       Fuel Types  \
# 0    340 km/h                   2.5 sec      $1,100,000   plug in hyrbrid
# 1    250 km/h                   5.3 sec        $460,000            Petrol
# 2    165 km/h                  10.5 sec  $12,000-$15,000           Petrol
# 3    250 km/h                   3.2 sec        $161,000            Petrol
# 4    320 km/h                   3.6 sec        $253,290            Petrol
#
#   Seats        Torque
# 0     2        800 Nm
# 1     5        900 Nm
# ...

# %%
cars.rename(columns={'Cars Prices':'Price'}, inplace=True)
cars.head(1)
# Out:
#   Company Names     Cars Names Engines CC/Battery Capacity HorsePower  \
# 0       FERRARI  SF90 STRADALE      V8             3990 cc     963 hp
#
#   Total Speed Performance(0 - 100 )KM/H        Price       Fuel Types Seats  \
# 0    340 km/h                   2.5 sec  $1,100,000   plug in hyrbrid     2
#
#    Torque
# 0  800 Nm

# %%
cars.isnull().sum()
# Out:
# Company Names                0
# Cars Names                   0
# Engines                      0
# CC/Battery Capacity          3
# HorsePower                   0
# Total Speed                  0
# Performance(0 - 100 )KM/H    6
# Price                        0
# Fuel Types                   0
# Seats                        0
# Torque                       1
# dtype: int64

# %%
cars[cars['Price'].str.contains('N')]
# Out:
#      Company Names         Cars Names            Engines CC/Battery Capacity  \
# 1147         Mazda  RX-Vision Concept  Rotary SkyActiv-R                 NaN
#
#          HorsePower      Total Speed Performance(0 - 100 )KM/H  \
# 1147  400 hp (est.)  300 km/h (est.)                       NaN
#
#                    Price       Fuel Types Seats Torque
# 1147  N/A (Concept Only)  Petrol (Hybrid)     2    NaN

# %%
len(cars)
# Out:
# 1218

# %%
cars.drop(1147, inplace=True, )
len(cars)
# Out:
# 1217

# %%
cars = cars.reset_index(drop=True)

# %%
cars[cars['Price'].str.contains('x')]
# Out:
# Empty DataFrame
# Columns: [Company Names, Cars Names, Engines, CC/Battery Capacity, HorsePower, Total Speed, Performance(0 - 100 )KM/H, Price, Fuel Types, Seats, Torque]
# Index: []

# %%
'\x96' in '43590 \x96 48000'
# Out:
# True

# %%
cars.loc[1216,:]
# Out:
# Company Names                                      Toyota
# Cars Names                                 RAV4 (6th Gen)
# Engines                      2.5L Hybrid / Plug-in Hybrid
# CC/Battery Capacity                        2487 cc + batt
# HorsePower                                   219  302 hp
# Total Speed                                      200 km/h
# Performance(0 - 100 )KM/H                   6.0  8.1 sec
# Price                                   $29,000  $43,000
# Fuel Types                               Hybrid / Plug-in
# Seats                                                   5
# Torque                                       221  400 Nm
# Name: 1216, dtype: str

# %%
'' in ' $29,000  $43,000'
# Out:
# True

# %%
cars['Price'] = cars['Price'].str.replace('','-').str.replace('','').str.replace('\x96','-').str.replace('\x80','-')

# %%
for r in range(len(cars)):

    # if '\x96' in cars['Price'][r]:
    #     cars.loc[r,7] = cars['Price'][r].replace('\x96','-')
    # if '\x80' in cars['Price'][r]:
    #     cars.loc[r,7] = cars['Price'][r].replace('\x80','-')
    # if '' in cars['Price'][r]:
    #     cars.loc[r,7] = cars['Price'][r].replace('','-')
        
    if '-' in cars['Price'][r]:
        price1 = int(cars['Price'][r].split('-')[0].replace('$','').replace(',','').strip())
        price2 = int(cars['Price'][r].split('-')[1].replace('$','').replace(',','').strip())
        price = (price1+price2)/2
        cars.iloc[r,7] = str(price)
        # cars['Price'][r] = price
        # print(price)
    elif '/' in cars['Price'][r]:
        price1 = int(cars['Price'][r].split('/')[0].replace('$','').replace(',','').strip())
        price2 = int(cars['Price'][r].split('/')[1].replace('$','').replace(',','').strip())
        price = (price1+price2)/2
        # cars['Price'][r] = price
        cars.iloc[r,7] = str(price)
        # print(price)
    else:
        # try:
        price = int(cars['Price'][r].replace('$','').replace(',','').strip())
        # print(price)
        cars.iloc[r,7] = str(price)

# %%
cars.head()
# Out:
#   Company Names     Cars Names      Engines CC/Battery Capacity HorsePower  \
# 0       FERRARI  SF90 STRADALE           V8             3990 cc     963 hp
# 1   ROLLS ROYCE        PHANTOM          V12             6749 cc     563 hp
# 2          Ford            KA+  1.2L Petrol            1,200 cc   70-85 hp
# 3      MERCEDES        GT 63 S           V8            3,982 cc     630 hp
# 4          AUDI     AUDI R8 Gt          V10            5,204 cc     602 hp
#
#   Total Speed Performance(0 - 100 )KM/H    Price       Fuel Types Seats  \
# 0    340 km/h                   2.5 sec  1100000  plug in hyrbrid     2
# 1    250 km/h                   5.3 sec   460000           Petrol     5
# 2    165 km/h                  10.5 sec  13500.0           Petrol     5
# 3    250 km/h                   3.2 sec   161000           Petrol     4
# 4    320 km/h                   3.6 sec   253290           Petrol     2
#
#          Torque
# 0        800 Nm
# 1        900 Nm
# 2  100 - 140 Nm
# ...

# %%
cars.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1217 entries, 0 to 1216
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Names              1217 non-null   str
#  1   Cars Names                 1217 non-null   str
#  2   Engines                    1217 non-null   str
#  3   CC/Battery Capacity        1215 non-null   str
#  4   HorsePower                 1217 non-null   str
#  5   Total Speed                1217 non-null   str
#  6   Performance(0 - 100 )KM/H  1212 non-null   str
#  7   Price                      1217 non-null   str
#  8   Fuel Types                 1217 non-null   str
#  9   Seats                      1217 non-null   str
#  10  Torque                     1217 non-null   str
# dtypes: str(11)
# memory usage: 205.1 KB

# %%
cars['Price'] = cars['Price'].astype(float)

cars.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1217 entries, 0 to 1216
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Names              1217 non-null   str
#  1   Cars Names                 1217 non-null   str
#  2   Engines                    1217 non-null   str
#  3   CC/Battery Capacity        1215 non-null   str
#  4   HorsePower                 1217 non-null   str
#  5   Total Speed                1217 non-null   str
#  6   Performance(0 - 100 )KM/H  1212 non-null   str
#  7   Price                      1217 non-null   float64
#  8   Fuel Types                 1217 non-null   str
#  9   Seats                      1217 non-null   str
#  10  Torque                     1217 non-null   str
# dtypes: float64(1), str(10)
# memory usage: 198.6 KB

# %%
cars.to_csv('cars.csv', index=False)

# %% [markdown]
# ---

# %%
import pandas as pd
phones = pd.read_csv('mobile_phones.csv')
laptops = pd.read_csv('laptops.csv')
cars = pd.read_csv('cars.csv')

# %%
phones.head()
# Out:
#   Company Name            Model Name  RAM Front Camera Back Camera  \
# 0        Apple       iPhone 16 128GB  6GB         12MP        48MP
# 1        Apple       iPhone 16 256GB  6GB         12MP        48MP
# 2        Apple       iPhone 16 512GB  6GB         12MP        48MP
# 3        Apple  iPhone 16 Plus 128GB  6GB         12MP        48MP
# 4        Apple  iPhone 16 Plus 256GB  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size  Price  Launched Year
# 0  A17 Bionic         3,600mAh  6.1 inches  799.0           2024
# 1  A17 Bionic         3,600mAh  6.1 inches  849.0           2024
# 2  A17 Bionic         3,600mAh  6.1 inches  899.0           2024
# 3  A17 Bionic         4,200mAh  6.7 inches  899.0           2024
# 4  A17 Bionic         4,200mAh  6.7 inches  949.0           2024

# %%
len(phones)
# Out:
# 1770

# %%
laptops.head()
# Out:
#      Brand                                               Name   Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  229.90
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  362.89
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  785.00
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  554.90
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  219.90
#
#              Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0        MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2  Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3  Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4  Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
#
#        RAM_TYPE                 Ghz Display_type Display  \
# ...

# %%
len(laptops)
# Out:
# 3976

# %%
cars.head()
# Out:
#   Company Names     Cars Names      Engines CC/Battery Capacity HorsePower  \
# 0       FERRARI  SF90 STRADALE           V8             3990 cc     963 hp
# 1   ROLLS ROYCE        PHANTOM          V12             6749 cc     563 hp
# 2          Ford            KA+  1.2L Petrol            1,200 cc   70-85 hp
# 3      MERCEDES        GT 63 S           V8            3,982 cc     630 hp
# 4          AUDI     AUDI R8 Gt          V10            5,204 cc     602 hp
#
#   Total Speed Performance(0 - 100 )KM/H      Price       Fuel Types Seats  \
# 0    340 km/h                   2.5 sec  1100000.0  plug in hyrbrid     2
# 1    250 km/h                   5.3 sec   460000.0           Petrol     5
# 2    165 km/h                  10.5 sec    13500.0           Petrol     5
# 3    250 km/h                   3.2 sec   161000.0           Petrol     4
# 4    320 km/h                   3.6 sec   253290.0           Petrol     2
#
#          Torque
# 0        800 Nm
# 1        900 Nm
# 2  100 - 140 Nm
# ...

# %%
len(cars)
# Out:
# 1217

# %%
phones.head(1)
# Out:
#   Company Name       Model Name  RAM Front Camera Back Camera   Processor  \
# 0        Apple  iPhone 16 128GB  6GB         12MP        48MP  A17 Bionic
#
#   Battery Capacity Screen Size  Price  Launched Year
# 0         3,600mAh  6.1 inches  799.0           2024

# %%
phones
# Out:
#      Company Name                                         Model Name  \
# 0           Apple                                    iPhone 16 128GB
# 1           Apple                                    iPhone 16 256GB
# 2           Apple                                    iPhone 16 512GB
# 3           Apple                               iPhone 16 Plus 128GB
# 4           Apple                               iPhone 16 Plus 256GB
# ...           ...                                                ...
# 1765          hmd  110 Dual Sim Keypad Phone with Built-in Scan &...
# 1766         vivo                  Y19s 5G (Majestic Green, 64.0 GB)
# 1767     MOTOROLA                 Edge 70 (PANTONE Lily Pad, 256 GB)
# 1768       realme                 P3 Ultra 5G (Neptune Blue, 128 GB)
# 1769     Kechaoda                                                A27
#
#                                                 RAM Front Camera  \
# 0                                               6GB         12MP
# ...

# %%
phones[(phones['Back Camera'].str.contains('\+'))]
# Out:
#      Company Name                          Model Name  \
# 6           Apple                 iPhone 16 Pro 128GB
# 7           Apple                 iPhone 16 Pro 256GB
# 8           Apple                 iPhone 16 Pro 512GB
# 9           Apple             iPhone 16 Pro Max 128GB
# 10          Apple             iPhone 16 Pro Max 256GB
# ...           ...                                 ...
# 1754       realme     P3 Pro 5G (Nebula Glow, 128 GB)
# 1762     MOTOROLA    Signature (PANTONE Carbon, 1 TB)
# 1766         vivo   Y19s 5G (Majestic Green, 64.0 GB)
# 1767     MOTOROLA  Edge 70 (PANTONE Lily Pad, 256 GB)
# 1768       realme  P3 Ultra 5G (Neptune Blue, 128 GB)
#
#                                                 RAM Front Camera  \
# 6                                               6GB    12MP / 4K
# 7                                               8GB    12MP / 4K
# 8                                               8GB    12MP / 4K
# ...

# %%
phones
# Out:
#      Company Name                                         Model Name  \
# 0           Apple                                    iPhone 16 128GB
# 1           Apple                                    iPhone 16 256GB
# 2           Apple                                    iPhone 16 512GB
# 3           Apple                               iPhone 16 Plus 128GB
# 4           Apple                               iPhone 16 Plus 256GB
# ...           ...                                                ...
# 1765          hmd  110 Dual Sim Keypad Phone with Built-in Scan &...
# 1766         vivo                  Y19s 5G (Majestic Green, 64.0 GB)
# 1767     MOTOROLA                 Edge 70 (PANTONE Lily Pad, 256 GB)
# 1768       realme                 P3 Ultra 5G (Neptune Blue, 128 GB)
# 1769     Kechaoda                                                A27
#
#                                                 RAM Front Camera  \
# 0                                               6GB         12MP
# ...

# %%
s = "samsung-apple-oppo"
companies = []
if s.__contains__('-'):
    companies = s.split('-')
companies
# Out:
# ['samsung', 'apple', 'oppo']

# %%
def search_phone(budget=0, company='', ram=0, front_camera=0, back_camera=0, multi_cameras=False):
    if budget:
        results = phones[(phones['Price']<=budget)]
    else:
        results = phones
    if company:
        if company.__contains__('-'):
            companies = company.split('-')
            result = pd.DataFrame()
            for c in companies:
                temp = results[(results['Company Name'].str.contains(c.strip(), case=False))]
                result = pd.concat([result,temp])
            results = result
        else:
            results = results[(results['Company Name'].str.contains(company, case=False))]
    if ram:
        # results = results[(results['RAM']>=ram)]
        # if not company.__contains__('apple'):
        results = pd.concat([results[(results['RAM'].str.contains(f"{ram} GB", case=False))],results[(results['RAM'].str.contains(f"{ram}GB", case=False))]])
    if front_camera:
        # results = results[(results['Front Camera']>=front_camera)]
        results = pd.concat([results[(results['Front Camera'].str.contains(f"{front_camera}MP", case=False))],results[(results['Front Camera'].str.contains(f"{front_camera} MP", case=False))]])
    if back_camera:
        # results = results[(results['Back Camera']>=back_camera)]
        # results = results[(results['Back Camera'].str.contains(back_camera, case=False))]
        results = pd.concat([results[(results['Back Camera'].str.contains(f"{back_camera}MP", case=False))],results[(results['Back Camera'].str.contains(f"{back_camera} MP", case=False))]])
    if multi_cameras:
        results = results[(results['Back Camera'].str.contains('\+'))]
    return results

# %%
results = search_phone(company='apple-samsung', ram=8, back_camera=8)
results
# Out:
#      Company Name                               Model Name  \
# 931         Apple                iPhone 16 (White, 128 GB)
# 933         Apple                iPhone 16 (Black, 128 GB)
# 935         Apple                 iPhone 16 (Teal, 128 GB)
# 937         Apple          iPhone 16 (Ultramarine, 128 GB)
# 941         Apple                 iPhone 16 (Pink, 128 GB)
# 956         Apple                iPhone 15 (Black, 128 GB)
# 1034        Apple                 iPhone 15 (Pink, 128 GB)
# 1052        Apple          iPhone 16 (Ultramarine, 128 GB)
# 1151        Apple                 iPhone 15 (Pink, 128 GB)
# 1148      Samsung  Galaxy A35 5G (Awesome Iceblue, 128 GB)
# 1172      Samsung            Galaxy F36 5G (Black, 128 GB)
# 1234      Samsung           Galaxy F36 5G (Violet, 128 GB)
# 1253      Samsung            Galaxy F36 5G (Black, 128 GB)
# 1317      Samsung      Galaxy S24 FE 5G (Graphite, 256 GB)
# 1318      Samsung      Galaxy S24 FE 5G (Graphite, 128 GB)
# ...

# %%
results = search_phone(800, company='apple',multi_cameras=True, back_camera=48)
results
# Out:
#      Company Name                       Model Name         RAM Front Camera  \
# 931         Apple        iPhone 16 (White, 128 GB)  128 GB ROM         12MP
# 933         Apple        iPhone 16 (Black, 128 GB)  128 GB ROM         12MP
# 935         Apple         iPhone 16 (Teal, 128 GB)  128 GB ROM         12MP
# 937         Apple  iPhone 16 (Ultramarine, 128 GB)  128 GB ROM         12MP
# 941         Apple         iPhone 16 (Pink, 128 GB)  128 GB ROM         12MP
# 956         Apple        iPhone 15 (Black, 128 GB)  128 GB ROM         12MP
# 1034        Apple         iPhone 15 (Pink, 128 GB)  128 GB ROM         12MP
# 1052        Apple  iPhone 16 (Ultramarine, 128 GB)  128 GB ROM         12MP
# 1151        Apple         iPhone 15 (Pink, 128 GB)  128 GB ROM         12MP
# 1384        Apple         iPhone 15 (Blue, 256 GB)  256 GB ROM         12MP
#
#       Back Camera                                    Processor  \
# 931   48MP + 12MP         A18 Chip, 6 Core Processor Processor
# ...

# %% [markdown]
# ---
# ---
